# %%
class BTNode:
  def __init__(self, elem):
    self.elem = elem
    self.right = None
    self.left = None

# %%
def inorder(root):
  if root == None:
    return

  inorder(root.left)
  print(root.elem, end = ' ')
  inorder(root.right)

# %%
def tree_construction(arr, i = 1):
  if i>=len(arr) or arr[i] == None:
    return None
  p = BTNode(arr[i])
  p.left = tree_construction(arr, 2*i)
  p.right = tree_construction(arr, 2*i+1)
  return p


root2 = tree_construction([None, 'A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', None, None, None, 'I', 'J', None, 'k'])
inorder(root2)
# Out:
# H D B E A I F J C G k

# %% [markdown]
# Task 1

# %%
def convert_mirror(root):
  if root==None:
    return
  convert_mirror(root.left)
  convert_mirror(root.right)

  root2=root.left
  root.left=root.right
  root.right=root2
  return root


#DRIVER CODE
root = BTNode(10)
n1 = BTNode(20)
n2 = BTNode(30)
n3 = BTNode(40)
n4 = BTNode(60)

root.left = n1
root.right = n2

n1.left = n3
n1.right = n4

print('Given Tree Inorder Traversal: ', end = ' ')
inorder(root) #Given Tree Inorder Traversal:  40 20 60 10 30
print()

root2 = convert_mirror(root)
print('Mirrored Tree Inorder Traversal: ', end = ' ')
inorder(root2) #Mirrored Tree Inorder Traversal:  30 10 60 20 40
# Out:
# Given Tree Inorder Traversal:  40 20 60 10 30
# Mirrored Tree Inorder Traversal:  30 10 60 20 40

# %% [markdown]
# Task 2

# %%
def largest_level(root,l=0,dic={}):

    if root==None:
        return

    if l in dic:
        if dic[l]<root.elem:
            dic[l]=root.elem
    else:
        dic[l]=root.elem

    largest_level(root.left,l+1,dic)
    largest_level(root.right,l+1,dic)
    return dic

#DRIVER CODE
root = tree_construction([None, 4,9,2,3,5,None,7])
print('Given Tree Inorder Traversal: ', end = ' ')
inorder(root) #Given Tree Inorder Traversal:  3 9 5 4 2 7
print()
print('Level Wise Largest Value: ', end = ' ')
print(largest_level(root)) #Level Wise Largest Value:  {0: 4, 1: 9, 2: 7}
# Out:
# Given Tree Inorder Traversal:  3 9 5 4 2 7
# Level Wise Largest Value:  {0: 4, 1: 9, 2: 7}

# %% [markdown]
# Task 3

# %%
def inorder_successor(root, x):
    if x.right!=None:
        temp=x.right
        while temp.left!=None:
            temp=temp.left
        return temp
    else:
        return "No Successor found"


#DRIVER CODE
root = BTNode(20)
n1 = BTNode(8)
n2 = BTNode(22)
n3 = BTNode(4)
n4 = BTNode(12)
n5 = BTNode(10)
n6 = BTNode(14)

root.left = n1
root.right = n2

n1.left = n3
n1.right = n4

n4.left = n5
n4.right = n6

print('Given Tree Inorder Traversal: ', end = ' ')
inorder(root) #Given Tree Inorder Traversal:  4 8 10 12 14 20 22
print()

x = n1
print(f'Inorder successor of node {x.elem}: {inorder_successor(root, x).elem}') #Inorder successor of node 8: 10
# Out:
# Given Tree Inorder Traversal:  4 8 10 12 14 20 22
# Inorder successor of node 8: 10

# %% [markdown]
# Task 4

# %%
def kth_smallest(root,k,i=1,dic={}):
    if root==None:
        return
    if i in dic:
        if dic[i].elem>root.elem:
            dic[i]=root
    else:
        dic[i]=root

    kth_smallest(root.left,k,i+1,dic)
    kth_smallest(root.right,k,i+1,dic)

    if k in dic:
        return dic[k]



#DRIVER CODE
root = tree_construction([None, 9,5,11,4,7,None,12,None,None,6,8,None,None,None,None])
print('Given Tree Inorder Traversal: ', end = ' ')
inorder(root)
print()
k = 4
print(kth_smallest(root,k).elem)
# Out:
# Given Tree Inorder Traversal:  4 5 6 7 8 9 11 12
# 6

# %% [markdown]
# Bonus

# %%
#WRITE THE FUNCTION AND DRIVER CODE BY YOURSELF

def sum_manual(root,l=1,total=0):
    if root==None:
        return total
    if l%2!=0:
        total=total+root.elem
    else:
        total=total-root.elem

    total=sum_manual(root.left,l+1,total)
    total=sum_manual(root.right,l+1,total)
    return total
#============================
root = BTNode(1)
n1 = BTNode(2)
n2 = BTNode(3)
n3 = BTNode(4)
n4 = BTNode(5)
n5 = BTNode(6)
n6 = BTNode(7)
n7 = BTNode(8)
#____________________
root.left = n1
root.right = n2
n1.left = n3
n2.left = n4
n2.right=n5
n4.right=n7
n4.left=n6
#==================
inorder(root)
print("\n")
print("="*25,'Sum',"="*25)
print("The difference between the levels are:",end=" ")
print(sum_manual(root))
# Out:
# 4 2 1 7 5 8 3 6
#
# ========================= Sum =========================
# The difference between the levels are: -4
